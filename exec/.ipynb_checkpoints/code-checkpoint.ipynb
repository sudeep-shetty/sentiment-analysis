# %%
import pandas as pd
from pandas import DataFrame
import re
import nltk
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np
from sklearn.ensemble import RandomForestClassifier

train = pd.read_csv("train1.csv",header=0,usecols=['text','airline_sentiment'])
example1 = train["text"][0]

def review_to_words( raw_review ):
    # Function to convert a raw review to a string of words
    # The input is a single string (a raw movie review), and 
    # the output is a single string (a preprocessed movie review)
    #
    # 1. Remove HTML
    #review_text = BeautifulSoup(raw_review).get_text() 
    #
    # 2. Remove non-letters        
    letters_only = re.sub("[^a-zA-Z]", " ", raw_review) 
    #
    # 3. Convert to lower case, split into individual words
    words = letters_only.lower().split()                             
    #
    # 4. In Python, searching a set is much faster than searching
    #   a list, so convert the stop words to a set
    stops = set(stopwords.words("english"))                  
    # 
    # 5. Remove stop words
    meaningful_words = [w for w in words if not w in stops]   
    #
    # 6. Join the words back into one string separated by space, 
    # and return the result.
    return( " ".join( meaningful_words ))

##################################################################
clean_review = review_to_words( train["text"][0] )
print clean_review

#################################################################
# Get the number of reviews based on the dataframe column size
num_reviews = train["text"].size

# Initialize an empty list to hold the clean reviews
clean_train_reviews = []

# Loop over each review; create an index i that goes from 0 to the length
# of the movie review list 
for i in xrange( 0, num_reviews ):
    # Call our function for each one, and add the result to the list of
    # clean reviews
    clean_train_reviews.append( review_to_words( train["text"][i] ) )
    
    ##############################################################
    
print "Cleaning and parsing the training set movie reviews...\n"
clean_train_reviews = []
for i in xrange( 0, num_reviews ):
    # If the index is evenly divisible by 1000, print a message
    if( (i+1)%1000 == 0 ):
        print "Review %d of %d\n" % ( i+1, num_reviews )                                                                    
    clean_train_reviews.append( review_to_words( train["text"][i] ))
    
    
######################################################################

print "Creating the bag of words...\n"

# Initialize the "CountVectorizer" object, which is scikit-learn's
# bag of words tool.  
vectorizer = CountVectorizer(analyzer = "word",   \
                             tokenizer = None,    \
                             preprocessor = None, \
                             stop_words = None,   \
                             max_features = 5000) 

# fit_transform() does two functions: First, it fits the model
# and learns the vocabulary; second, it transforms our training data
# into feature vectors. The input to fit_transform should be a list of 
# strings.
train_data_features = vectorizer.fit_transform(clean_train_reviews)

# Numpy arrays are easy to work with, so convert the result to an 
# array
train_data_features = train_data_features.toarray()


#################################################################################

# Take a look at the words in the vocabulary
vocab = vectorizer.get_feature_names()
print vocab


#################################################################################

# Sum up the counts of each vocabulary word
dist = np.sum(train_data_features, axis=0)

# For each, print the vocabulary word and the number of times it 
# appears in the training set
for tag, count in zip(vocab, dist):
    print count, tag
    
    
################################################################################
forest = RandomForestClassifier(n_estimators = 100) 

# Fit the forest to the training set, using the bag of words as 
# features and the sentiment labels as the response variable
#
# This may take a few minutes to run
forest = forest.fit( train_data_features, train["airline_sentiment"] )
# Read the test data
test = pd.read_csv("test1.csv", header=0)
#test = pd.read_csv("b.csv",header=0,usecols=['text','airline_sentiment'])

# Verify that there are 25,000 rows and 2 columns
print test.shape

# Create an empty list and append the clean reviews one by one
num_reviews = test["text"].size
clean_test_reviews = [] 

print "Cleaning and parsing the test set movie reviews...\n"
for i in xrange(0,num_reviews):
    if( (i+1) % 1000 == 0 ):
        print "Review %d of %d\n" % (i+1, num_reviews)
    clean_review = review_to_words( test["text"][i] )
    clean_test_reviews.append( clean_review )

# Get a bag of words for the test set, and convert to a numpy array
test_data_features = vectorizer.transform(clean_test_reviews)
test_data_features = test_data_features.toarray()

# Use the random forest to make sentiment label predictions
result = forest.predict(test_data_features)

# Copy the results to a pandas dataframe with an "id" column and
# a "sentiment" column
output = pd.DataFrame( data={"_unit_id":test["_unit_id"], "airline_sentiment":result} )

# Use pandas to write the comma-separated output file
output.to_csv( "result.csv", index=False, quoting=3 )
print ("done final")
# Out:
# virginamerica dhepburn said
# Cleaning and parsing the training set movie reviews...
#
# Review 1000 of 11698
#
# Review 2000 of 11698
#
# Review 3000 of 11698
#
# Review 4000 of 11698
#
# Review 5000 of 11698
#
# Review 6000 of 11698
#
# Review 7000 of 11698
#
# Review 8000 of 11698
#
# Review 9000 of 11698
#
# Review 10000 of 11698
#
# Review 11000 of 11698
#
# Creating the bag of words...
#
# [u'aa', u'aadvantage', u'aarp', u'abc', u'abcnetwork', u'ability', u'able', u'aboard', u'abq', u'abroad', u'absolute', u'absolutely', u'absurd', u'abt', u'abused', u'abysmal', u'ac', u'accept', u'acceptable', u'accepted', u'accepting', u'access', u'accident', u'accidentally', u'accommodate', u'accommodated', u'accommodating', u'accommodation', u'accommodations', u'accomplished', u'according', u'accordingly', u'account', u'accountability', u'accounts', u'acct', u'accurate', u'acknowledge', u'across', u'act', u'action', u'actions', u'active', u'activities', u'actual', u'actually', u'ad', u'adam', u'add', u'added', u'adding', u'addition', u'additional', u'address', u'addressed', u'addresses', u'addressing', u'adds', u'addtl', u'admirals', u'admit', u'adopted', u'adopting', u'ads', u'adult', u'advance', u'advantage', u'advertise', u'advertising', u'advice', u'advise', u'advisory', u'aerojobmarket', u'affect', u'affected', u'affecting', u'afford', u'affordable', u'afraid', u'afterall', u'afternoon', u'age', u'agency', u'agent', u'agents', u'ages', u'aggressive', u'ago', u'agree', u'agt', u'ah', u'ahead', u'ahhhh', u'ahold', u'ailing', u'air', u'airborne', u'airbus', u'aircanada', u'aircraft', u'airfare', u'airline', u'airlinegeeks', u'airlines', u'airnzusa', u'airplane', u'airplanes', u'airport', u'airports', u'airways', u'aisle', u'aka', u'al', u'alan', u'alas', u'alaskaair', u'albany', u'albuquerque', u'alcohol', u'alert', u'alerted', u'alerts', u'ali', u'alive', u'allergic', u'allergies', u'allergy', u'alliance', u'allow', u'allowance', u'allowed', u'allowing', u'allows', u'almost', u'alone', u'along', u'alot', u'already', u'alright', u'also', u'alt', u'alternate', u'alternatives', u'although', u'altitude', u'always', u'alwayslate', u'amateurish', u'amazed', u'amazing', u'amazingly', u'amazon', u'america', u'american', u'americanair', u'americanairlines', u'amex', u'among', u'amongst', u'amount', u'amp', u'ams', u'amsterdam', u'amybruni', u'ana', u'anamarketers', u'anchorage', u'andrews', u'android', u'angel', u'angeles', u'angry', u'anku', u'ann', u'annettenaif', u'anniversary', u'announce', u'announced', u'announcement', u'announcements', u'announces', u'announcing', u'annoyed', u'annoying', u'annricord', u'annual', u'another', u'answer', u'answered', u'answering', u'answers', u'ant', u'anthony', u'anticipate', u'antigua', u'antonio', u'anxiety', u'anxious', u'anybody', u'anymore', u'anyone', u'anything', u'anytime', u'anyway', u'anywhere', u'ap', u'apart', u'apologies', u'apologize', u'apologizes', u'apologizing', u'apology', u'app', u'appalled', u'apparent', u'apparently', u'appear', u'appeared', u'appears', u'appease', u'apple', u'applepay', u'applicable', u'application', u'applied', u'apply', u'applying', u'appointments', u'appreciate', u'appreciated', u'appreciates', u'appreciation', u'approach', u'approaching', u'appropriate', u'approve', u'approved', u'approx', u'apps', u'apr', u'april', u'apt', u'aqjn', u'ar', u'ardent', u'area', u'argue', u'argued', u'argument', u'arizona', u'armrest', u'arms', u'army', u'around', u'arrange', u'arranged', u'arrangements', u'arrival', u'arrive', u'arrived', u'arrives', u'arriving', u'art', u'article', u'aruba', u'asap', u'ase', u'ashamed', u'ashley', u'asia', u'aside', u'ask', u'asked', u'asking', u'askpaypal', u'asks', u'asleep', u'aspen', u'ass', u'assaulted', u'asset', u'assets', u'asshole', u'assign', u'assigned', u'assignment', u'assignments', u'assist', u'assistance', u'assisting', u'associated', u'assume', u'assuming', u'assure', u'assured', u'astounding', u'atc', u'ath', u'athlete', u'athletes', u'atl', u'atlanta', u'atlantic', u'atleast', u'atrocious', u'attached', u'attempt', u'attempting', u'attend', u'attendant', u'attendants', u'attention', u'attentiveness', u'attitude', u'attitudes', u'atx', u'au', u'aug', u'august', u'aus', u'austin', u'austinairport', u'australia', u'austrian', u'auto', u'automated', u'automatically', u'autoresponse', u'av', u'avail', u'availability', u ...
# 44 aa
# 4 aadvantage
# 3 aarp
# 9 abc
# 3 abcnetwork
# 4 ability
# 89 able
# 4 aboard
# 6 abq
# 2 abroad
# 18 absolute
# 22 absolutely
# 11 absurd
# 5 abt
# 2 abused
# 5 abysmal
# 5 ac
# 11 accept
# 16 acceptable
# 7 accepted
# 6 accepting
# 34 access
# 3 accident
# 4 accidentally
# 13 accommodate
# 2 accommodated
# 2 accommodating
# 2 accommodation
# 5 accommodations
# 2 accomplished
# 9 according
# 3 accordingly
# 70 account
# 4 accountability
# 7 accounts
# 8 acct
# 7 accurate
# 4 acknowledge
# 11 across
# 13 act
# 4 action
# 6 actions
# 4 active
# 3 activities
# 17 actual
# 70 actually
# 4 ad
# 2 adam
# 67 add
# 20 added
# 17 adding
# 4 addition
# 11 additional
# 33 address
# 4 addressed
# 2 addresses
# 2 addressing
# 6 adds
# 2 addtl
# 6 admirals
# 4 admit
# 2 adopted
# 3 adopting
# 4 ads
# 2 adult
# 9 advance
# 9 advantage
# 5 advertise
# 5 advertising
# 7 advice
# 11 advise
# 21 advisory
# 2 aerojobmarket
# 2 affect
# 10 affected
# 2 affecting
# 11 afford
# 3 affordable
# 2 afraid
# 2 afterall
# 25 afternoon
# 7 age
# 6 agency
# 170 agent
# 112 agents
# 4 ages
# 3 aggressive
# 109 ago
# 7 agree
# 3 agt
# 11 ah
# 15 ahead
# 3 ahhhh
# 4 ahold
# 2 ailing
# 112 air
# 2 airborne
# 9 airbus
# 7 aircanada
# 28 aircraft
# 10 airfare
# 324 airline
# 3 airlinegeeks
# 124 airlines
# 2 airnzusa
# 20 airplane
# 3 airplanes
# 278 airport
# 20 airports
# 71 airways
# 5 aisle
# 5 aka
# 2 al
# 2 alan
# 2 alas
# 2 alaskaair
# 6 albany
# 3 albuquerque
# 2 alcohol
# 8 alert
# 2 alerted
# 6 alerts
# 4 ali
# 5 alive
# 2 allergic
# 2 allergies
# 2 allergy
# 8 alliance
# 19 allow
# 2 allowance
# 29 allowed
# 7 allowing
# 4 allows
# 75 almost
# 17 alone
# 17 along
# 4 alot
# 146 already
# 8 alright
# 104 also
# 2 alt
# 10 alternate
# 3 alternatives
# 10 although
# 3 altitude
# 87 always
# 2 alwayslate
# 2 amateurish
# 2 amazed
# 87 amazing
# 2 amazingly
# 2 amazon
# 15 america
# 41 american
# 185 americanair
# 3 americanairlines
# 4 amex
# 7 among
# 2 amongst
# 15 amount
# 546 amp
# 2 ams
# 2 amsterdam
# 3 amybruni
# 4 ana
# 4 anamarketers
# 2 anchorage
# 3 andrews
# 3 android
# 2 angel
# 2 angeles
# 15 angry
# 2 anku
# 2 ann
# 2 annettenaif
# 8 anniversary
# 9 announce
# 13 announced
# 13 announcement
# 7 announcements
# 2 announces
# 2 announcing
# 7 annoyed
# 10 annoying
# 5 annricord
# 5 annual
# 204 another
# 73 answer
# 16 answered
# 25 answering
# 24 answers
# 2 ant
# 4 anthony
# 4 anticipate
# 2 antigua
# 3 antonio
# 2 anxiety
# 4 anxious
# 2 anybody
# 23 anymore
# 80 anyone
# 93 anything
# 9 anytime
# 22 anyway
# 20 anywhere
# 2 ap
# 8 apart
# 14 apologies
# 6 apologize
# 2 apologizes
# 2 apologizing
# 35 apology
# 90 app
# 4 appalled
# 3 apparent
# 30 apparently
# 7 appear
# 2 appeared
# 8 appears
# 19 appease
# 9 apple
# 2 applepay
# 2 applicable
# 5 application
# 13 applied
# 15 apply
# 2 applying
# 3 appointments
# 96 appreciate
# 27 appreciated
# 2 appreciates
# 3 appreciation
# 6 approach
# 2 approaching
# 4 appropriate
# 4 approve
# 4 approved
# 2 approx
# 4 apps
# 3 apr
# 14 april
# 3 apt
# 3 aqjn
# 3 ar
# 2 ardent
# 27 area
# 2 argue
# 3 argued
# 3 argument
# 4 arizona
# 5 armrest
# 3 arms
# 2 army
# 54 around
# 3 arrange
# 3 arranged
# 4 arrangements
# 27 arrival
# 41 arrive
# 49 arrived
# 18 arrives
# 24 arriving
# 2 art
# 6 article
# 5 aruba
# 34 asap
# 6 ase
# 6 ashamed
# 2 ashley
# 2 asia
# 2 aside
# 43 ask
# 51 asked
# 35 asking
# 4 askpaypal
# 2 asks
# 4 asleep
# 6 aspen
# 8 ass
# 4 assaulted
# 2 asset
# 2 assets
# 2 asshole
# 4 assign
# 10 assigned
# 5 assignment
# 3 assignments
# 21 assist
# 37 assistance
# 3 assisting
# 2 associated
# 6 assume
# 3 assuming
# 2 assure
# 4 assured
# 2 astounding
# 4 atc
# 2 ath
# 3 athlete
# 2 athletes
# 38 atl
# 35 atlanta
# 5 atlantic
# 2 atleast
# 6 atrocious
# 2 attached
# 12 attempt
# 4 attempting
# 7 attend
# 78 attendant
# 45 attendants
# 8 attention
# 2 attentiveness
# 25 attitude
# 3 attitudes
# 2 atx
# 4 au
# 8 aug
# 12 august
# 16 aus
# 33 austin
# 2 austinairport
# 11 australia
# 3 austrian
# 15 auto
# 17 automated
# 13 automatically
# 2 autoresponse
# 4 av
# 12 avail
# 6 availability
# 88 available
# 4 average
# 2 averted
# 19 avgeek
# 11 aviation
# 2 avis
# 5 aviv
# 9 avoid
# 2 avon
# 3 aw
# 7 awaiting
# 3 awake
# 26 award
# 7 awards
# 10 aware
# 66 away
# 5 awe
# 105 awesome
# 2 awesomeness
# 48 awful
# 2 awhile
# 4 awkward
# 3 aww
# 3 awww
# 2 ay
# 4 az
# 2 ba
# 3 babies
# 27 baby
# 373 back
# 3 backlog
# 2 backroads
# 3 backs
# 6 backup
# 136 bad
# 14 badcustomerservice
# 2 badge
# 5 badges
# 9 badly
# 2 badpolicy
# 19 badservice
# 6 bae
# 398 bag
# 4 bagage
# 189 baggage
# 2 baggagelost
# 2 baggages
# 222 bags
# 5 bahamas
# 2 bait
# 10 balance
# 8 ball
# 4 balls
# 7 baltimore
# 8 band
# 2 bandwidth
# 2 bangkok
# 19 bank
# 4 bankrupt
# 5 bar
# 2 barbara
# 7 barely
# 3 base
# 11 based
# 4 basic
# 9 basically
# 2 basket
# 8 bathroom
# 3 battery
# 2 battierccipuppy
# 3 batting
# 18 battles
# 2 battling
# 7 bay
# 61 bc
# 2 bd
# 15 bday
# 13 bdl
# 10 beach
# 3 beamske
# 6 beat
# 5 beats
# 2 beatsmusic
# 2 beatz
# 12 beautiful
# 3 beauty
# 12 become
# 4 becoming
# 3 bed
# 7 beer
# 2 beers
# 3 beg
# 2 began
# 10 begin
# 5 beginning
# 2 begins
# 2 behave
# 2 behavior
# 21 behind
# 2 bein
# 2 belfast
# 37 believe
# 2 believing
# 5 belize
# 2 bellagio
# 2 belong
# 3 belongings
# 7 belt
# 2 bench
# 2 beneficial
# 5 benefit
# 7 benefits
# 2 bereavement
# 2 bergstrom
# 6 besides
# 157 best
# 4 bestairline
# 2 bestairlineever
# 2 bestemployees
# 2 bestflightever
# 2 bestfriends
# 2 besty
# 9 bet
# 2 betsy
# 147 better
# 2 beverage
# 2 beverages
# 3 beware
# 26 beyond
# 5 bf
# 2 bff
# 2 bg
# 2 bgm
# 3 bgr
# 6 bhm
# 59 big
# 2 bigger
# 6 biggest
# 3 bike
# 5 bill
# 2 billing
# 10 bin
# 7 bins
# 2 bio
# 14 bird
# 6 birmingham
# 4 birth
# 2 birthdate
# 29 birthday
# 19 bit
# 3 bitch
# 10 biz
# 2 bizarre
# 4 bk
# 3 bkk
# 10 black
# 2 blackhistorymonth
# 3 blah
# 13 blame
# 5 blamed
# 2 blames
# 5 blaming
# 3 blank
# 2 blankets
# 2 blast
# 4 blasting
# 3 blatant
# 2 bless
# 3 blew
# 2 blizzard
# 2 block
# 3 blocked
# 7 blog
# 3 bloody
# 2 blowing
# 3 blown
# 46 blue
# 2 bluecarpet
# 8 bluemanity
# 2 blumanity
# 2 bm
# 31 bna
# 98 board
# 39 boarded
# 159 boarding
# 11 boards
# 3 boat
# 4 boeing
# 2 bogot
# 7 bogota
# 4 boise
# 2 bold
# 2 bom
# 5 bonus
# 4 boo
# 146 book
# 136 booked
# 117 booking
# 5 books
# 2 boooo
# 4 booze
# 2 bora
# 3 border
# 2 born
# 93 bos
# 5 boss
# 84 boston
# 6 bostonlogan
# 13 bother
# 4 bothered
# 3 bottle
# 4 bottles
# 4 bottom
# 36 bought
# 3 bougth
# 2 bounce
# 2 bounced
# 3 bound
# 2 bourbon
# 4 box
# 5 boy
# 3 boycott
# 4 boyfriend
# 2 boys
# 2 bqn
# 2 bradley
# 2 brain
# 9 brand
# 4 brandloveaffair
# 5 brandmance
# 2 brands
# 2 brandssayingbae
# 2 bravo
# 2 brazil
# 2 breach
# 11 break
# 2 breakdown
# 6 breakfast
# 5 breaking
# 3 breaks
# 3 breast
# 2 bretharold
# 2 brian
# 5 bridge
# 3 bright
# 6 brilliant
# 38 bring
# 11 bringing
# 2 british
# 3 bro
# 2 broadway
# 16 broke
# 57 broken
# 2 brokenpromises
# 12 brother
# 4 brothers
# 8 brought
# 5 browser
# 3 browsers
# 4 bruh
# 2 brussels
# 5 brutal
# 20 bs
# 2 bttr
# 5 btv
# 20 btw
# 2 bucket
# 6 bucks
# 3 buddies
# 4 budget
# 15 buf
# 13 buffalo
# 7 bug
# 2 build
# 2 bulkhead
# 2 bull
# 7 bullshit
# 2 bummed
# 7 bummer
# 5 bump
# 20 bumped
# 2 bumper
# 5 bumping
# 7 bunch
# 2 burger
# 2 burn
# 2 burning
# 2 burningman
# 17 bus
# 5 bush
# 2 busiest
# 106 business
# 2 businessfirst
# 3 bussey
# 24 busy
# 3 butt
# 5 button
# 2 buttons
# 36 buy
# 3 buyer
# 7 buying
# 3 bv
# 57 bwi
# 2 bye
# 7 ca
# 13 cab
# 28 cabin
# 2 cable
# 6 cabo
# 4 cae
# 2 caffeine
# 5 cake
# 2 calendar
# 4 calgary
# 4 cali
# 11 california
# 304 call
# 6 callback
# 89 called
# 49 calling
# 29 calls
# 29 came
# 6 camera
# 2 camp
# 2 campilley
# 4 cana
# 8 canada
# 4 canadian
# 714 cancelled
# 3 cancer
# 12 cancun
# 2 caned
# 5 canned
# 33 cannot
# 34 cant
# 2 cap
# 3 capa
# 2 capable
# 3 capacity
# 3 capital
# 5 capt
# 22 captain
# 3 captive
# 2 capture
# 55 car
# 70 card
# 2 cardholder
# 4 cards
# 115 care
# 2 cared
# 8 cares
# 3 cargo
# 2 caribbean
# 4 caring
# 2 carol
# 3 carolina
# 13 carousel
# 3 carpet
# 2 carrie
# 3 carried
# 7 carrier
# 9 carriers
# 13 carrieunderwood
# 45 carry
# 6 carrying
# 8 carryon
# 3 carryons
# 4 carseat
# 2 carsl
# 7 cart
# 44 case
# 2 cases
# 7 cash
# 23 catch
# 2 catching
# 2 catered
# 4 catering
# 2 cattle
# 4 caught
# 26 cause
# 20 caused
# 6 causes
# 9 causing
# 4 cb
# 18 cc
# 2 ce
# 2 celebrate
# 2 celebrates
# 3 celebrating
# 10 cell
# 3 cellphone
# 16 center
# 2 centers
# 4 central
# 2 centricity
# 3 century
# 49 ceo
# 3 cert
# 7 certain
# 8 certainly
# 12 certificate
# 3 certificates
# 3 cessna
# 2 cf
# 2 ch
# 2 cha
# 6 chair
# 14 chairman
# 2 chairmans
# 6 chairs
# 3 challenge
# 2 challenges
# 67 chance
# 13 chances
# 220 change
# 57 changed
# 40 changes
# 25 changing
# 3 channel
# 6 channels
# 4 chaos
# 2 char
# 7 characters
# 61 charge
# 31 charged
# 8 charges
# 19 charging
# 6 charity
# 2 charles
# 8 charleston
# 54 charlotte
# 3 charm
# 2 chart
# 3 charter
# 5 chase
# 7 chat
# 17 cheap
# 12 cheaper
# 4 cheapflights
# 3 cheated
# 245 check
# 104 checked
# 35 checkin
# 37 checking
# 4 checkout
# 3 cheer
# 12 cheers
# 4 cheese
# 9 chi
# 67 chicago
# 5 chicken
# 23 child
# 13 children
# 4 chill
# 3 china
# 4 cho
# 4 chocolate
# 17 choice
# 3 choices
# 15 choose
# 4 choosing
# 3 chose
# 3 christmas
# 4 chrome
# 3 chs
# 3 cincy
# 4 circumstances
# 14 cities
# 37 city
# 80 claim
# 5 claimed
# 3 claiming
# 8 claims
# 3 clarification
# 3 clarify
# 3 clarifying
# 100 class
# 5 classy
# 12 cle
# 12 clean
# 8 cleaned
# 3 cleaning
# 18 clear
# 12 clearly
# 7 cleveland
# 4 clever
# 7 click
# 4 clicking
# 6 client
# 7 clients
# 13 close
# 24 closed
# 5 closer
# 5 closest
# 31 clothes
# 3 clothing
# 2 cloud
# 2 clouds
# 2 clown
# 89 clt
# 38 club
# 3 clubs
# 13 clue
# 3 cluster
# 2 clutch
# 17 cmh
# 4 cmon
# 2 cng
# 4 cnn
# 2 cnnmoney
# 2 cnx
# 2 cnxn
# 1075 co
# 15 coach
# 9 coast
# 5 coat
# 2 coats
# 2 cockpit
# 2 cocktail
# 25 code
# 2 codes
# 2 codeshare
# 18 coffee
# 4 coincidence
# 3 coke
# 28 cold
# 3 colleague
# 2 collect
# 4 collection
# 7 college
# 2 colo
# 2 colombia
# 4 color
# 3 columbia
# 11 columbus
# 13 com
# 2 combination
# 4 comcast
# 93 come
# 2 comedy
# 8 comes
# 4 comfort
# 6 comfortable
# 57 coming
# 2 comm
# 9 comment
# 4 comments
# 11 commercial
# 6 commercials
# 4 commitment
# 3 committed
# 8 common
# 6 communicate
# 2 communicated
# 35 communication
# 2 communicationfail
# 3 communications
# 3 community
# 8 comp
# 2 companies
# 41 companion
# 64 company
# 2 compare
# 3 compared
# 7 compassion
# 2 compatible
# 2 comped
# 16 compensate
# 6 compensated
# 2 compensating
# 29 compensation
# 2 competent
# 3 competition
# 2 competitor
# 2 competitors
# 11 complain
# 2 complained
# 2 complaining
# 2 complains
# 36 complaint
# 17 complaints
# 20 complete
# 3 completed
# 32 completely
# 2 compliant
# 4 compliment
# 9 complimentary
# 2 compliments
# 2 comps
# 39 computer
# 11 computers
# 4 con
# 2 concentrate
# 3 concept
# 19 concern
# 11 concerned
# 7 concerns
# 3 concert
# 6 concourse
# 2 condition
# 10 conditions
# 2 condom
# 2 conection
# 25 conf
# 8 conference
# 3 confidence
# 2 confident
# 25 confirm
# 63 confirmation
# 2 confirmations
# 34 confirmed
# 3 confirming
# 4 conflicting
# 6 confused
# 3 confusing
# 5 confusion
# 16 congrats
# 4 congratulations
# 19 connect
# 9 connected
# 79 connecting
# 126 connection
# 27 connections
# 3 connector
# 2 connects
# 4 consecutive
# 12 consider
# 2 considerable
# 2 consideration
# 4 considered
# 9 considering
# 8 consistent
# 7 consistently
# 5 constant
# 5 constantly
# 2 construction
# 2 consumer
# 3 consumers
# 7 cont
# 74 contact
# 10 contacted
# 6 contacting
# 2 contains
# 5 content
# 12 contest
# 6 continental
# 13 continue
# 4 continued
# 7 continues
# 3 continuing
# 5 contract
# 24 control
# 2 conversation
# 2 conversations
# 3 cookies
# 53 cool
# 8 copy
# 3 corp
# 14 corporate
# 7 corporation
# 36 correct
# 3 corrected
# 8 correctly
# 44 cost
# 3 costa
# 2 costing
# 10 costs
# 8 costumer
# 183 could
# 5 couldnt
# 18 count
# 2 counted
# 30 counter
# 44 counting
# 24 country
# 14 couple
# 5 coupon
# 4 coupons
# 2 courier
# 26 course
# 3 court
# 5 courteous
# 12 courtesy
# 4 cousin
# 19 cover
# 3 coverage
# 2 covered
# 2 covering
# 3 coworker
# 3 coworkers
# 3 cp
# 2 cpap
# 2 cr
# 4 crackers
# 2 craft
# 2 cramped
# 4 cranky
# 11 crap
# 10 crappy
# 5 crash
# 6 crashed
# 2 crashes
# 5 crashing
# 3 craziness
# 25 crazy
# 2 cream
# 3 create
# 7 created
# 2 creates
# 2 creative
# 96 credit
# 6 credited
# 9 credits
# 194 crew
# 3 crewmember
# 3 crewmembers
# 8 crews
# 2 cried
# 2 criminal
# 5 crisis
# 14 cross
# 18 crossed
# 3 crowd
# 2 crowded
# 4 cruise
# 5 cry
# 7 crying
# 14 cs
# 7 csr
# 2 css
# 4 ct
# 6 ctl
# 6 cuba
# 3 culture
# 11 cun
# 6 cup
# 2 curb
# 2 curbside
# 2 curiosity
# 7 curious
# 19 current
# 41 currently
# 2 cus
# 2 cushion
# 2 cushions
# 48 cust
# 2 custexp
# 588 customer
# 134 customers
# 29 customerservice
# 4 customerservicefail
# 5 customs
# 3 custserv
# 14 cut
# 5 cute
# 4 cutting
# 9 cuz
# 6 cvg
# 7 cx
# 5 cxl
# 2 da
# 13 dad
# 2 dads
# 17 daily
# 2 dakota
# 23 dal
# 2 dale
# 50 dallas
# 5 dallaslovefield
# 5 damage
# 11 damaged
# 2 damages
# 17 damn
# 2 dan
# 2 danahajek
# 3 dance
# 5 dancing
# 3 dang
# 4 dark
# 4 darn
# 5 data
# 30 date
# 9 dates
# 24 daughter
# 5 daughters
# 7 david
# 267 day
# 173 days
# 4 daytona
# 50 dc
# 102 dca
# 2 dcoadavon
# 16 de
# 10 dead
# 3 deadhead
# 2 deaf
# 44 deal
# 21 dealing
# 19 deals
# 5 dealt
# 5 dear
# 10 death
# 4 debacle
# 2 debating
# 2 debit
# 6 december
# 5 decent
# 5 decide
# 9 decided
# 2 deciding
# 8 decision
# 5 decisions
# 4 deck
# 2 decline
# 2 deedee
# 6 deep
# 5 def
# 2 defend
# 6 define
# 2 defines
# 21 definitely
# 2 definition
# 2 definitive
# 8 degree
# 7 degrees
# 3 deicing
# 4 del
# 257 delay
# 465 delayed
# 13 delaying
# 127 delays
# 3 delete
# 4 deleted
# 3 delhi
# 2 delight
# 2 delighted
# 15 deliver
# 32 delivered
# 2 delivering
# 16 delivery
# 77 delta
# 2 deltaassist
# 52 den
# 2 denairport
# 17 denied
# 81 denver
# 2 denverairport
# 3 deny
# 2 deodorant
# 2 dep
# 22 depart
# 7 departed
# 16 departing
# 16 department
# 10 departs
# 78 departure
# 6 departures
# 9 deplane
# 5 deplaned
# 2 deplaning
# 2 deplorable
# 13 dept
# 3 derrick
# 2 describe
# 2 describing
# 2 desert
# 7 deserve
# 5 deserved
# 13 deserves
# 6 design
# 5 designed
# 51 desk
# 2 desks
# 4 desktop
# 4 desperately
# 2 despicable
# 26 despite
# 3 dest
# 50 destination
# 2 destinationdragon
# 83 destinationdragons
# 6 destinations
# 3 destroyed
# 4 detail
# 2 detailed
# 30 details
# 2 determined
# 2 detroit
# 4 develop
# 2 developers
# 2 development
# 8 device
# 4 devices
# 26 dfw
# 14 dia
# 3 dial
# 10 didnt
# 6 die
# 5 died
# 16 diego
# 11 diff
# 16 difference
# 66 different
# 12 difficult
# 3 difficulties
# 6 digital
# 4 dime
# 7 dinner
# 75 direct
# 7 directed
# 8 directly
# 6 directtv
# 8 dirty
# 3 disabled
# 5 disappeared
# 6 disappoint
# 88 disappointed
# 16 disappointing
# 9 disappointment
# 13 disaster
# 5 disconnect
# 29 disconnected
# 3 disconnects
# 9 discount
# 6 discounts
# 3 discovered
# 4 discrimination
# 8 discuss
# 4 disgrace
# 3 disgruntled
# 5 disgusted
# 13 disgusting
# 7 disney
# 3 display
# 4 disregard
# 5 disrespect
# 3 disrespectful
# 4 dissatisfied
# 3 distribution
# 4 div
# 3 divert
# 10 diverted
# 25 dividend
# 3 dividends
# 222 dm
# 8 dmed
# 3 dming
# 3 dms
# 5 dobetter
# 3 document
# 6 doesnt
# 9 dog
# 4 dollar
# 12 dollars
# 21 domestic
# 4 donate
# 4 donation
# 104 done
# 30 dont
# 21 door
# 9 doors
# 3 dot
# 14 double
# 8 doubt
# 3 doug
# 5 downgrade
# 3 downhill
# 6 download
# 3 downtown
# 4 dozen
# 3 dozens
# 4 dpt
# 6 dr
# 7 dragon
# 18 dragons
# 10 dragonss
# 7 dream
# 3 dreams
# 19 drink
# 10 drinks
# 31 drive
# 5 driven
# 5 driver
# 12 driving
# 18 drop
# 18 dropped
# 4 dropping
# 3 drops
# 7 drove
# 7 drunk
# 2 drunks
# 5 dry
# 5 dsm
# 7 dtw
# 2 dub
# 2 dublin
# 3 dude
# 188 due
# 3 duffle
# 4 duh
# 16 dulles
# 2 dultch
# 6 dumb
# 2 dumped
# 4 dunno
# 2 duped
# 3 durango
# 2 duty
# 7 dying
# 2 dz
# 2 eagle
# 77 earlier
# 2 earliest
# 90 early
# 2 earlybird
# 11 earn
# 10 earned
# 6 earth
# 2 earthquake
# 11 easier
# 4 easiest
# 12 easily
# 9 east
# 7 eastern
# 34 easy
# 9 eat
# 2 eb
# 3 eco
# 3 econ
# 13 economy
# 7 ed
# 2 edinburgh
# 2 education
# 2 ef
# 5 efficiency
# 4 efficient
# 9 effort
# 6 efforts
# 2 eight
# 30 either
# 3 el
# 2 elaborate
# 4 elderly
# 10 elevate
# 2 eligible
# 9 elite
# 2 eliz
# 6 ella
# 3 ellahenderson
# 2 elm
# 43 else
# 8 elsewhere
# 6 em
# 179 email
# 15 emailed
# 2 emailing
# 18 emails
# 3 embarrassed
# 6 embarrassing
# 4 embossed
# 2 embraersa
# 14 emergency
# 2 emily
# 3 empathy
# 32 employee
# 65 employees
# 2 employer
# 37 empty
# 2 ems
# 2 emv
# 5 en
# 3 encountered
# 46 end
# 11 ended
# 3 endless
# 2 endlessly
# 3 ends
# 2 energy
# 2 enforcing
# 14 engine
# 10 english
# 15 enjoy
# 3 enjoyable
# 7 enjoyed
# 5 enjoying
# 54 enough
# 4 enquires
# 2 enroll
# 5 enroute
# 4 ensure
# 2 ensuring
# 13 enter
# 4 entered
# 3 entering
# 2 enterprise
# 3 entertain
# 3 entertaining
# 24 entertainment
# 35 entire
# 2 entirely
# 3 entitled
# 3 entry
# 2 enuf
# 2 environment
# 2 eofthgaj
# 2 ep
# 7 epic
# 10 epicfail
# 2 epicfailunited
# 3 equal
# 3 equally
# 18 equipment
# 6 er
# 3 eri
# 3 erj
# 45 error
# 10 errors
# 4 es
# 5 esp
# 20 especially
# 7 est
# 6 estimate
# 9 estimated
# 6 eta
# 14 etc
# 3 ethiopia
# 3 etihad
# 3 eu
# 6 europe
# 6 evaluate
# 219 even
# 22 evening
# 13 event
# 13 eventually
# 191 ever
# 103 every
# 2 everybody
# 70 everyone
# 44 everything
# 6 everytime
# 3 everywhere
# 3 evry
# 94 ewr
# 3 ex
# 11 exact
# 12 exactly
# 13 example
# 2 exceed
# 2 excellence
# 23 excellent
# 19 except
# 5 exception
# 4 exceptional
# 2 exceptions
# 7 exchange
# 26 excited
# 2 exclusively
# 18 excuse
# 6 excuses
# 3 exec
# 2 execution
# 3 executive
# 2 exercise
# 4 exhausted
# 3 exist
# 2 existence
# 8 existent
# 9 existing
# 3 exists
# 16 exit
# 6 exp
# 2 expanding
# 34 expect
# 3 expectations
# 21 expected
# 9 expecting
# 7 expedia
# 2 expedient
# 4 expedited
# 2 expense
# 2 expenses
# 16 expensive
# 172 experience
# 15 experienced
# 10 experiences
# 3 experiencing
# 2 expiration
# 4 expire
# 16 expired
# 8 expires
# 3 expiring
# 27 explain
# 10 explained
# 19 explanation
# 2 explanations
# 5 explorer
# 2 exposed
# 9 express
# 2 expressed
# 6 extend
# 8 extended
# 6 extension
# 2 extent
# 68 extra
# 5 extreme
# 24 extremely
# 7 ey
# 6 eye
# 7 eyes
# 3 eyw
# 10 fa
# 12 faa
# 3 faanews
# 2 fab
# 6 fabulous
# 6 face
# 5 facebook
# 3 faces
# 6 facing
# 31 fact
# 80 fail
# 22 failed
# 6 failing
# 9 fails
# 18 failure
# 3 failures
# 12 fair
# 3 fairs
# 4 faith
# 3 fake
# 6 fall
# 5 falling
# 3 fallow
# 9 false
# 10 fam
# 7 families
# 76 family
# 16 fan
# 8 fans
# 16 fantastic
# 68 far
# 33 fare
# 4 farecompare
# 21 fares
# 17 fast
# 12 faster
# 3 fastest
# 3 fat
# 9 father
# 27 fault
# 6 fav
# 4 fave
# 3 favor
# 20 favorite
# 2 fax
# 8 fb
# 4 fc
# 2 fd
# 2 fe
# 8 feature
# 30 feb
# 12 february
# 2 feces
# 2 fed
# 52 fee
# 3 feed
# 25 feedback
# 46 feel
# 9 feeling
# 12 feels
# 31 fees
# 12 feet
# 4 fell
# 3 fella
# 12 felt
# 2 female
# 3 fend
# 3 ferry
# 2 festival
# 2 festivities
# 3 fewer
# 5 ff
# 3 ffl
# 11 fi
# 4 fianc
# 4 fiasco
# 7 field
# 2 fields
# 10 fight
# 31 figure
# 14 figured
# 18 file
# 19 filed
# 2 filing
# 15 fill
# 16 filled
# 3 filling
# 3 film
# 2 filmjobnoequipment
# 2 films
# 2 filthy
# 15 final
# 104 finally
# 2 finals
# 4 financial
# 130 find
# 2 finder
# 12 finding
# 33 fine
# 4 finest
# 2 finger
# 20 fingers
# 5 finish
# 6 fire
# 5 fired
# 217 first
# 4 firstclass
# 2 firstworldproblems
# 10 fit
# 4 fits
# 13 five
# 72 fix
# 26 fixed
# 4 fixing
# 22 fl
# 6 flat
# 3 flattering
# 2 flaw
# 2 flawed
# 152 fleek
# 152 fleet
# 40 flew
# 3 flex
# 3 flexibility
# 2 flexible
# 3 flgt
# 7 flier
# 8 fliers
# 5 flies
# 3101 flight
# 6 flightation
# 7 flightations
# 4 flightaware
# 19 flightd
# 156 flighted
# 34 flighting
# 27 flightlation
# 26 flightlations
# 332 flightled
# 14 flightling
# 8 flightly
# 129 flightr
# 533 flights
# 4 flightst
# 3 flite
# 57 fll
# 13 floor
# 15 florida
# 3 flowers
# 30 flown
# 124 flt
# 6 flts
# 333 fly
# 4 flydelta
# 25 flyer
# 14 flyers
# 12 flyfi
# 277 flying
# 12 flyingitforward
# 5 flyitforward
# 4 flylaxairport
# 3 flysfo
# 3 flysouthwest
# 7 flytpa
# 4 flyunited
# 2 fm
# 2 fo
# 2 focused
# 5 folder
# 2 folding
# 2 folk
# 23 folks
# 113 follow
# 17 followed
# 2 followers
# 31 following
# 4 follows
# 50 food
# 2 foolish
# 4 foot
# 2 force
# 22 forced
# 5 forces
# 7 forcing
# 2 forecast
# 2 forecasted
# 2 forecasts
# 2 foreign
# 15 forever
# 2 forfeited
# 8 forget
# 4 forgetting
# 4 forgive
# 2 forgiven
# 17 forgot
# 40 form
# 5 formal
# 3 formally
# 2 former
# 4 forms
# 2 formula
# 13 fort
# 4 forth
# 4 fortunately
# 12 fortunemagazine
# 47 forward
# 68 found
# 31 four
# 5 fq
# 4 fr
# 9 fra
# 5 fran
# 2 franchise
# 9 francisco
# 2 frank
# 6 frankfurt
# 2 frankly
# 11 fraud
# 8 freaking
# 117 free
# 13 freezing
# 5 freq
# 2 frequency
# 21 frequent
# 2 frequentflyer
# 5 fresh
# 2 fresno
# 2 freyabevan
# 2 freyasfund
# 29 friday
# 51 friend
# 3 friendliest
# 30 friendly
# 4 friendlyskies
# 28 friends
# 3 frigid
# 2 fritz
# 10 frm
# 31 front
# 3 frontier
# 2 frontrunner
# 9 frozen
# 57 frustrated
# 42 frustrating
# 10 frustration
# 2 frustrations
# 2 fs
# 10 ft
# 4 ftw
# 2 fu
# 16 fuck
# 5 fucked
# 2 fucken
# 16 fucking
# 12 fuel
# 2 fueled
# 2 fuk
# 78 full
# 5 fully
# 31 fun
# 3 functionality
# 3 functioning
# 2 fund
# 12 funds
# 15 funeral
# 18 funny
# 6 furious
# 3 furrow
# 32 future
# 2 fwiw
# 2 fx
# 17 fyi
# 4 ga
# 2 gaga
# 4 gain
# 3 gainesville
# 2 gains
# 2 gal
# 4 galley
# 18 game
# 2 gangway
# 9 garbage
# 5 gary
# 2 gas
# 412 gate
# 19 gates
# 2 gatwick
# 63 gave
# 2 gay
# 2 gb
# 8 gear
# 3 gee
# 3 geeks
# 3 geg
# 8 general
# 7 generic
# 2 genius
# 2 gent
# 2 gentleman
# 2 gents
# 2 gesture
# 1005 get
# 6 getaway
# 5 getittogether
# 28 gets
# 3 gettin
# 193 getting
# 5 gf
# 2 gfc
# 9 gg
# 2 giant
# 6 gift
# 11 girl
# 7 girlfriend
# 4 girls
# 135 give
# 52 given
# 29 gives
# 31 giving
# 5 gj
# 44 glad
# 3 gladly
# 2 glasgow
# 4 glass
# 3 glasses
# 4 glitch
# 2 glitches
# 14 global
# 4 globe
# 2 gluten
# 3 gma
# 5 gmail
# 2 gng
# 3 gnv
# 258 go
# 4 goal
# 18 god
# 25 goes
# 2 gogh
# 3 gogo
# 3 goin
# 244 going
# 3 goingforgreatnessfail
# 25 gold
# 9 golf
# 24 gone
# 31 gonna
# 236 good
# 2 goodenoughmother
# 2 goodflight
# 2 goodness
# 2 goodnight
# 2 goods
# 5 goodwill
# 4 google
# 2 gopro
# 4 gorgeous
# 3 gosh
# 350 got
# 3 gotcha
# 11 gotta
# 14 gotten
# 4 gr
# 3 grace
# 4 gracias
# 7 grand
# 3 grandfather
# 7 grandma
# 4 grateful
# 286 great
# 5 greatservice
# 3 greedy
# 6 green
# 5 greenville
# 5 greeting
# 3 greetings
# 5 gross
# 71 ground
# 5 grounded
# 43 group
# 6 grr
# 3 gso
# 87 gt
# 10 guarantee
# 3 guaranteed
# 49 guess
# 3 guessing
# 4 guest
# 4 guests
# 6 guide
# 3 guidelines
# 7 guitar
# 4 guitars
# 41 guy
# 292 guys
# 14 ha
# 26 haha
# 3 hahaha
# 5 haiti
# 60 half
# 4 halfway
# 6 hand
# 4 handed
# 23 handle
# 12 handled
# 3 handler
# 5 handlers
# 12 handling
# 9 hands
# 17 hang
# 3 hangar
# 4 hanger
# 6 hanging
# 5 hangs
# 32 happen
# 44 happened
# 21 happening
# 33 happens
# 3 happier
# 4 happily
# 3 happiness
# 71 happy
# 3 happycustomer
# 4 harbor
# 47 hard
# 5 harder
# 4 hardly
# 3 hardworking
# 11 hare
# 6 hartford
# 3 hashtag
# 7 hassle
# 33 hate
# 6 hates
# 4 haul
# 4 havent
# 15 hawaii
# 4 hayden
# 3 hayes
# 4 hdn
# 11 head
# 17 headed
# 13 heading
# 5 headphones
# 9 heads
# 3 health
# 50 hear
# 45 heard
# 11 hearing
# 10 heart
# 8 heat
# 9 heathrow
# 2 heathrowairport
# 2 heaven
# 5 heavily
# 5 heavy
# 6 heck
# 2 helacohlc
# 26 held
# 19 hell
# 28 hello
# 644 help
# 30 helped
# 78 helpful
# 33 helping
# 5 helps
# 2 hemisphere
# 9 hence
# 2 hep
# 2 herman
# 4 hero
# 53 hey
# 2 hh
# 79 hi
# 3 hidden
# 2 hide
# 26 high
# 10 higher
# 4 highlight
# 5 highly
# 6 hilarious
# 17 hire
# 7 hiring
# 2 historical
# 9 history
# 10 hit
# 4 hits
# 3 hitting
# 2 hj
# 4 hmmm
# 2 hn
# 7 hnl
# 504 hold
# 4 holder
# 6 holders
# 30 holding
# 2 holds
# 3 holdup
# 2 hole
# 2 holiday
# 2 holidays
# 3 holy
# 237 home
# 2 homeless
# 14 honest
# 8 honestly
# 2 honesty
# 3 honey
# 8 honeymoon
# 4 honolulu
# 15 honor
# 4 honored
# 3 honoring
# 8 hook
# 5 hooked
# 2 hooking
# 2 hoot
# 3 hop
# 102 hope
# 3 hoped
# 4 hopeful
# 36 hopefully
# 3 hopeless
# 2 hopes
# 42 hoping
# 2 horrendous
# 69 horrible
# 2 horriblecustomerservice
# 2 horribleservice
# 5 horrid
# 2 horrific
# 2 horror
# 2 horse
# 3 hospitality
# 9 hostage
# 4 hosting
# 16 hot
# 114 hotel
# 11 hotels
# 3 hotline
# 2 hotmail
# 2 hotspot
# 2 hotter
# 7 hou
# 402 hour
# 2 hourdelay
# 501 hours
# 8 house
# 3 housing
# 60 houston
# 23 however
# 4 hp
# 8 hpn
# 97 hr
# 3 hrl
# 230 hrs
# 1019 http
# 53 https
# 3 hub
# 6 hubby
# 2 hug
# 30 huge
# 3 hugely
# 6 huh
# 34 human
# 3 humans
# 2 humiliating
# 4 humor
# 2 humour
# 3 hundred
# 7 hundreds
# 64 hung
# 6 hungry
# 10 hunt
# 3 huntsville
# 6 hurt
# 25 husband
# 2 huston
# 5 hv
# 3 hwnac
# 2 hy
# 3 hypocrisy
# 60 iad
# 48 iah
# 2 iamtedking
# 24 ice
# 3 iced
# 2 iceland
# 10 icing
# 3 icy
# 28 id
# 49 idea
# 2 ideal
# 6 ideas
# 2 identical
# 3 idiot
# 7 idiots
# 3 idk
# 2 iflyswa
# 4 ignore
# 4 ignored
# 2 ignores
# 6 ignoring
# 2 ilc
# 7 ill
# 5 illegal
# 46 im
# 17 imagine
# 46 imaginedragons
# 2 imma
# 3 immediate
# 5 immediately
# 2 imo
# 6 impact
# 2 impending
# 14 important
# 13 impossible
# 2 impress
# 16 impressed
# 3 impression
# 2 impressions
# 4 impressive
# 10 improve
# 3 improved
# 2 improvement
# 2 improvements
# 3 inability
# 3 inaccurate
# 4 inadequate
# 4 inappropriate
# 11 inbound
# 2 inbox
# 2 inc
# 6 incentive
# 3 inch
# 4 inches
# 9 incident
# 5 inclement
# 9 include
# 6 included
# 2 includes
# 9 including
# 5 incoming
# 10 incompetence
# 12 incompetent
# 2 inconsistent
# 27 inconvenience
# 2 inconvenienced
# 7 inconvenient
# 2 inconvience
# 3 incorrect
# 3 increase
# 4 increased
# 2 increasing
# 8 incredible
# 15 incredibly
# 4 incur
# 6 ind
# 6 indeed
# 2 india
# 3 indianapolis
# 3 indicated
# 2 indicates
# 2 indication
# 3 individual
# 6 industry
# 5 indy
# 4 inefficient
# 3 inept
# 3 inevitable
# 6 inexcusable
# 14 infant
# 2 infants
# 2 inferior
# 19 inflight
# 112 info
# 5 inform
# 42 information
# 2 informative
# 12 informed
# 7 ing
# 6 initial
# 2 injured
# 3 injury
# 4 innovation
# 2 input
# 5 ins
# 11 insane
# 2 insanity
# 14 inside
# 2 insight
# 2 insist
# 2 inspected
# 8 inspired
# 2 instagram
# 81 instead
# 3 instructed
# 2 instructions
# 2 instruments
# 3 insufficient
# 4 insult
# 4 insulting
# 9 int
# 2 intact
# 2 integrate
# 3 integration
# 2 intelligent
# 2 intend
# 2 intended
# 2 intent
# 3 intentionally
# 3 interaction
# 3 intercom
# 8 interest
# 4 interested
# 7 interesting
# 2 intern
# 3 internal
# 46 international
# 3 internationally
# 14 internet
# 2 internjohnradio
# 11 interview
# 16 intl
# 2 intro
# 3 invalid
# 2 invest
# 2 investigate
# 2 investigated
# 2 investor
# 2 investors
# 3 invite
# 2 invited
# 2 involved
# 6 ios
# 2 iowa
# 15 ipad
# 13 iphone
# 5 irritated
# 2 irritating
# 2 irrops
# 2 ish
# 3 isis
# 3 island
# 2 islands
# 5 isnt
# 2 isp
# 114 issue
# 14 issued
# 104 issues
# 2 issuing
# 3 italy
# 13 item
# 9 items
# 2 itineraries
# 14 itinerary
# 9 ive
# 4 ivr
# 2 jabevan
# 5 jac
# 4 jack
# 2 jackass
# 3 jacked
# 3 jacket
# 2 jackson
# 3 jacksonville
# 3 jacquie
# 3 jailbreak
# 2 jam
# 4 jamaica
# 9 jan
# 3 jane
# 3 janet
# 7 january
# 2 jason
# 8 jax
# 4 jayvig
# 22 jb
# 14 jblu
# 3 jeanine
# 3 jedediahbila
# 5 jeff
# 2 jenniferwalshpr
# 3 jeokoo
# 2 jerk
# 50 jet
# 4 jetbae
# 2387 jetblue
# 2 jetblueblues
# 2 jetbluebos
# 2 jetbluecheeps
# 2 jetbluefail
# 3 jetbluerocks
# 3 jetbluesofly
# 3 jets
# 13 jetway
# 2 jezziegoldz
# 149 jfk
# 11 jh
# 2 ji
# 2 jim
# 2 jimcramer
# 2 jimmy
# 4 jj
# 3 jk
# 2 jkf
# 2 jm
# 3 jms
# 66 job
# 3 jobs
# 2 joe
# 5 john
# 7 join
# 2 joined
# 34 joke
# 2 joking
# 3 jon
# 6 jose
# 2 josephtreis
# 16 journal
# 5 journey
# 7 jp
# 7 jt
# 3 jtrexsocial
# 11 juan
# 3 julie
# 4 july
# 6 jump
# 2 jumped
# 2 jun
# 6 june
# 2 junk
# 2 justify
# 5 jvmchat
# 3 jx
# 2 karajusto
# 7 karen
# 6 kc
# 2 kci
# 3 kciairport
# 98 keep
# 17 keeping
# 26 keeps
# 6 kelly
# 2 kentuckymbb
# 20 kept
# 2 kevin
# 2 kewl
# 3 key
# 2 kf
# 4 kgdh
# 2 ki
# 3 kick
# 6 kicked
# 6 kid
# 17 kidding
# 58 kids
# 5 kill
# 2 killed
# 10 killing
# 2 kim
# 31 kind
# 5 kinda
# 4 kindle
# 3 kindness
# 4 king
# 3 kiosk
# 5 kiosks
# 3 kit
# 2 kj
# 6 kn
# 3 knees
# 26 knew
# 286 know
# 11 knowing
# 2 knowledge
# 13 known
# 23 knows
# 2 knoxville
# 2 korea
# 13 kp
# 4 kphl
# 3 kq
# 5 ktn
# 26 kudos
# 2 kul
# 2 kv
# 4 kylejudah
# 37 la
# 36 lack
# 5 ladies
# 23 lady
# 12 ladygaga
# 8 laguardia
# 5 lake
# 10 lame
# 26 land
# 70 landed
# 50 landing
# 8 lands
# 6 lap
# 8 laptop
# 10 large
# 3 larger
# 2 larry
# 48 las
# 3 lasairport
# 255 last
# 344 late
# 11 lauderdale
# 3 laugh
# 2 laurasbrown
# 8 lauren
# 3 lavatory
# 6 law
# 2 laws
# 2 lawsuit
# 114 lax
# 28 layover
# 3 layovers
# 5 lazy
# 2 lb
# 8 lbs
# 3 ld
# 5 lead
# 2 leadership
# 5 leading
# 2 league
# 25 learn
# 8 learned
# 2 learning
# 69 least
# 87 leave
# 12 leaves
# 63 leaving
# 2 led
# 150 left
# 33 leg
# 5 legal
# 3 legit
# 2 legitimate
# 11 legroom
# 7 legs
# 2 leinenkugels
# 2 lemme
# 56 less
# 10 lesson
# 177 let
# 10 lets
# 4 letsgo
# 15 letter
# 3 letters
# 23 letting
# 11 level
# 2 lexington
# 2 lf
# 2 lft
# 3 lfulcbq
# 45 lga
# 2 lgb
# 4 lh
# 11 lhr
# 2 liable
# 2 liars
# 6 license
# 16 lie
# 8 lied
# 11 lies
# 48 life
# 7 lifetime
# 9 light
# 3 lighting
# 3 lights
# 340 like
# 3 likelihood
# 15 likely
# 2 likes
# 3 lil
# 7 limit
# 6 limited
# 4 lindsey
# 123 line
# 18 lines
# 64 link
# 4 linked
# 2 linking
# 3 lisa
# 40 list
# 11 listed
# 8 listen
# 16 listening
# 2 lit
# 20 literally
# 59 little
# 2 littlebirds
# 32 live
# 8 livery
# 6 lives
# 2 livid
# 6 living
# 3 lj
# 5 lmao
# 4 lmfao
# 3 lo
# 21 load
# 8 loaded
# 5 loading
# 4 loads
# 2 loaner
# 2 loc
# 7 local
# 3 locals
# 8 locate
# 5 located
# 7 location
# 5 locations
# 2 lock
# 4 locked
# 2 lodge
# 4 lodging
# 11 log
# 13 logan
# 3 logged
# 2 logging
# 3 logic
# 5 login
# 48 lol
# 13 london
# 3 lone
# 148 long
# 52 longer
# 78 look
# 10 looked
# 97 looking
# 50 looks
# 2 looong
# 2 loooooong
# 4 loose
# 3 loosing
# 3 lord
# 2 los
# 35 lose
# 2 losers
# 7 loses
# 22 losing
# 4 loss
# 203 lost
# 2 lostluggage
# 51 lot
# 25 lots
# 2 loud
# 6 louis
# 2 louisville
# 25 lounge
# 2 lounges
# 7 lousy
# 220 love
# 15 loved
# 4 lovejetblue
# 14 lovely
# 5 loves
# 3 lovesongfriday
# 7 loving
# 12 low
# 8 lower
# 4 lowered
# 3 lowest
# 44 loyal
# 12 loyalty
# 39 lt
# 2 lucia
# 25 luck
# 7 luckily
# 9 lucky
# 8 lufthansa
# 208 luggage
# 2 luggages
# 3 lunch
# 2 lusaka
# 38 luv
# 3 luvswa
# 2 luxuries
# 2 luxurious
# 2 lv
# 2 lx
# 3 lying
# 3 lynn
# 2 maatkare
# 2 mac
# 6 machine
# 11 mad
# 2 maddening
# 156 made
# 4 madness
# 4 magazine
# 4 magic
# 4 maiden
# 20 mail
# 2 mailing
# 2 mails
# 3 maimi
# 12 main
# 2 maine
# 3 maint
# 2 maintained
# 46 maintenance
# 21 major
# 245 make
# 56 makes
# 2 makeup
# 91 making
# 7 male
# 5 malfunction
# 2 mama
# 24 man
# 9 manage
# 7 managed
# 12 management
# 9 manager
# 3 managers
# 2 manch
# 5 manchester
# 2 maneuver
# 5 manner
# 3 manually
# 82 many
# 5 map
# 3 marathon
# 25 march
# 3 mardigras
# 3 marie
# 8 mark
# 2 marked
# 4 market
# 10 marketing
# 2 markie
# 5 marks
# 4 married
# 2 marriott
# 2 martysg
# 2 mary
# 3 mass
# 4 massive
# 2 masters
# 21 match
# 2 mates
# 3 math
# 24 matter
# 3 matters
# 2 max
# 60 may
# 64 maybe
# 3 mayweatherpacquiao
# 3 mb
# 3 mc
# 7 mci
# 49 mco
# 2 md
# 2 mde
# 17 mdw
# 18 meal
# 7 meals
# 48 mean
# 2 meaning
# 2 meaningful
# 26 means
# 10 meant
# 3 meantime
# 2 measure
# 7 mech
# 58 mechanical
# 10 mechanics
# 2 medal
# 22 media
# 7 medical
# 10 meet
# 19 meeting
# 6 meetings
# 2 meh
# 2 mel
# 4 mem
# 48 member
# 26 members
# 5 membership
# 2 memo
# 2 memorial
# 3 memories
# 2 memory
# 11 memphis
# 2 men
# 12 mention
# 4 mentioned
# 3 menu
# 2 menus
# 2 mercy
# 2 mere
# 7 merge
# 5 merged
# 17 merger
# 4 merging
# 22 mess
# 55 message
# 4 messaged
# 11 messages
# 12 messed
# 2 messing
# 14 met
# 3 metal
# 8 method
# 3 metro
# 3 mex
# 19 mexico
# 3 mht
# 4 mi
# 13 mia
# 26 miami
# 2 michaelbcoleman
# 8 mid
# 30 middle
# 3 middleeast
# 2 mideast
# 2 midght
# 4 midland
# 12 midnight
# 12 midway
# 60 might
# 2 mike
# 8 mile
# 27 mileage
# 17 mileageplus
# 4 miler
# 139 miles
# 13 military
# 6 million
# 201 min
# 20 mind
# 27 mine
# 3 minneapolis
# 10 minor
# 124 mins
# 16 mint
# 50 minute
# 253 minutes
# 2 miriam
# 9 miserable
# 2 misfortune
# 3 misleading
# 3 misplaced
# 131 miss
# 101 missed
# 2 misses
# 93 missing
# 4 mission
# 13 mistake
# 5 mistakes
# 2 mix
# 6 mke
# 2 ml
# 3 mn
# 2 mnl
# 27 mobile
# 8 model
# 2 modifications
# 2 modify
# 27 mom
# 10 moment
# 4 moments
# 3 momma
# 4 moms
# 13 mon
# 41 monday
# 71 money
# 5 monitor
# 39 month
# 2 monthly
# 35 months
# 2 mood
# 2 moodlighting
# 2 moodlitmonday
# 3 moon
# 117 morning
# 2 morrow
# 2 mos
# 7 mosaic
# 3 mostly
# 2 motel
# 15 mother
# 2 motto
# 2 mountains
# 3 mouse
# 24 move
# 32 moved
# 2 movement
# 7 movie
# 3 movies
# 21 moving
# 2 mp
# 3 mph
# 6 mr
# 2 mrerickv
# 3 ms
# 2 msbgu
# 10 msg
# 2 msgs
# 11 msp
# 10 msy
# 4 mt
# 3 mths
# 189 much
# 3 multi
# 27 multiple
# 3 murdering
# 17 music
# 2 musician
# 3 musicians
# 35 must
# 3 mv
# 3 mvp
# 3 myers
# 2 myrtle
# 7 nah
# 83 name
# 5 named
# 8 names
# 2 naming
# 7 nantucket
# 2 nap
# 2 narita
# 2 nas
# 2 nascar
# 4 nasdaq
# 41 nashville
# 4 nassau
# 8 nasty
# 5 national
# 4 nature
# 2 naxbue
# 2 nbr
# 2 nburnside
# 14 nc
# 45 nd
# 10 near
# 4 nearby
# 13 nearly
# 3 necessary
# 408 need
# 38 needed
# 5 needing
# 65 needs
# 2 neglect
# 3 negligence
# 4 negotiate
# 2 neighbors
# 5 neither
# 3 nephew
# 2 neptune
# 2 nerdbird
# 6 nervous
# 4 network
# 274 never
# 21 neveragain
# 3 neverflyvirginforbusiness
# 214 new
# 61 newark
# 2 newburgh
# 3 newly
# 2 neworleans
# 30 news
# 2 newyork
# 181 next
# 8 nexus
# 6 nh
# 2 nhlonnbcsports
# 104 nice
# 6 nicely
# 3 nicer
# 2 nigga
# 113 night
# 17 nightmare
# 5 nights
# 2 ninadavuluri
# 3 nite
# 11 nj
# 2 njairports
# 4 nl
# 3 nm
# 12 nobody
# 2 nocrew
# 2 nocustomerservice
# 2 noexcuses
# 2 nofun
# 2 nogood
# 5 nola
# 4 nolove
# 40 non
# 17 none
# 3 nonexistent
# 2 nonprofit
# 2 nonrefundable
# 3 nonsense
# 18 nonstop
# 6 noon
# 3 noooo
# 27 nope
# 2 noplacelikehome
# 4 norfolk
# 4 norm
# 9 normal
# 4 normally
# 6 north
# 5 northeast
# 2 noservice
# 5 notch
# 8 notcool
# 23 note
# 3 noted
# 5 notes
# 3 notgoodenough
# 3 nothanks
# 11 nothappy
# 3 nothin
# 116 nothing
# 15 notice
# 8 noticed
# 2 noticing
# 14 notification
# 7 notifications
# 10 notified
# 9 notify
# 4 notimpressed
# 5 november
# 3 nowhere
# 2 nrhodes
# 4 nrt
# 3 nt
# 4 ntrustopen
# 2 num
# 175 number
# 12 numbers
# 4 numerous
# 11 nuts
# 2 nvm
# 3 nvr
# 2 nw
# 3 nxt
# 31 ny
# 64 nyc
# 4 nytimes
# 6 oak
# 6 oakland
# 3 obj
# 2 obnoxious
# 2 observe
# 2 obvious
# 11 obviously
# 3 oc
# 4 occurred
# 4 oct
# 7 october
# 5 odd
# 3 odds
# 2 offensive
# 53 offer
# 31 offered
# 26 offering
# 9 offers
# 21 office
# 4 officer
# 2 offices
# 11 official
# 14 officially
# 2 offload
# 12 often
# 5 ogg
# 72 oh
# 6 ohare
# 2 ohio
# 2 oil
# 2 ojrsdwpkk
# 86 ok
# 34 okay
# 8 okc
# 72 old
# 3 oma
# 5 omaha
# 15 omg
# 19 onboard
# 445 one
# 11 ones
# 2 onhold
# 3 onholdwith
# 142 online
# 2 ons
# 2 ont
# 4 ontime
# 14 onto
# 2 ooh
# 5 oops
# 3 opal
# 85 open
# 7 opened
# 7 opening
# 4 opens
# 5 operate
# 5 operated
# 7 operating
# 5 operation
# 5 operational
# 7 operations
# 2 operator
# 3 operators
# 2 opportunities
# 10 opportunity
# 2 opposed
# 3 opposite
# 2 ops
# 2 opt
# 54 option
# 37 options
# 2 oq
# 2 oqukso
# 3 orangecounty
# 2 orbitz
# 88 ord
# 2 ordeal
# 21 order
# 2 ordered
# 3 orf
# 2 org
# 4 organization
# 4 orig
# 2 origin
# 32 original
# 11 originally
# 2 orl
# 36 orlando
# 5 orleans
# 2 os
# 3 oscar
# 27 oscars
# 20 others
# 13 otherwise
# 3 otis
# 2 ottawa
# 2 ouch
# 2 oui
# 2 ourprincess
# 2 outage
# 8 outbound
# 3 outdated
# 12 outlets
# 3 outrageous
# 12 outside
# 5 outsource
# 2 outsourcing
# 11 outstanding
# 5 overall
# 3 overbook
# 16 overbooked
# 2 overcharged
# 3 overflight
# 2 overflowed
# 27 overhead
# 2 overheard
# 2 overheating
# 26 overnight
# 2 overpriced
# 3 overseas
# 3 oversize
# 2 oversized
# 4 oversold
# 4 overweight
# 2 overwhelmed
# 2 overwhelming
# 2 ow
# 5 owe
# 3 owner
# 3 oz
# 10 pa
# 2 pacific
# 3 pack
# 2 package
# 4 packages
# 5 packed
# 2 packing
# 26 page
# 2 pages
# 81 paid
# 3 pain
# 7 painful
# 3 painless
# 2 paint
# 9 pair
# 12 palm
# 2 panamerican
# 2 pandora
# 2 panic
# 3 pants
# 12 paper
# 2 papers
# 7 paperwork
# 2 par
# 2 parachuteguy
# 3 parent
# 9 parents
# 7 paris
# 4 park
# 5 parked
# 4 parking
# 31 part
# 3 partial
# 4 particularly
# 2 partly
# 10 partner
# 6 partners
# 5 partnership
# 21 party
# 2 paso
# 84 pass
# 26 passbook
# 11 passed
# 33 passenger
# 155 passengers
# 18 passes
# 4 passing
# 2 passion
# 2 passive
# 7 passport
# 7 password
# 57 past
# 4 paste
# 3 pat
# 4 patches
# 3 path
# 9 pathetic
# 15 patience
# 14 patient
# 3 patiently
# 2 patronizing
# 2 patterns
# 2 pattonoswalt
# 2 paulgordonbrown
# 2 paulo
# 10 pax
# 102 pay
# 3 payed
# 36 paying
# 8 payment
# 4 paypal
# 4 pays
# 16 pbi
# 2 pd
# 15 pdx
# 3 peace
# 3 peanut
# 10 peanuts
# 2 pedro
# 3 peeps
# 4 pen
# 6 penalty
# 5 pending
# 3 pens
# 227 people
# 16 per
# 14 perfect
# 2 perfectly
# 4 perfectomobile
# 2 perform
# 4 performance
# 3 performing
# 13 perhaps
# 7 period
# 3 perk
# 2 permanently
# 2 permission
# 89 person
# 15 personal
# 2 personalized
# 5 personally
# 7 personnel
# 2 perspective
# 3 perth
# 4 pet
# 2 pf
# 2 pg
# 2 pgatour
# 2 pgh
# 6 ph
# 2 phd
# 2 phi
# 3 phil
# 20 philadelphia
# 4 philippines
# 54 philly
# 106 phl
# 18 phlairport
# 2 phn
# 2 pho
# 22 phoenix
# 294 phone
# 21 phones
# 8 photo
# 2 photography
# 54 phx
# 3 phxskyharbor
# 2 physical
# 3 physically
# 3 pia
# 7 pic
# 37 pick
# 15 picked
# 6 picking
# 2 picks
# 2 pics
# 10 picture
# 11 piece
# 2 pig
# 4 pile
# 5 pillows
# 79 pilot
# 44 pilots
# 2 pin
# 3 ping
# 2 pink
# 3 piss
# 10 pissed
# 12 pit
# 2 pitt
# 9 pittsburgh
# 2 pj
# 2 pjs
# 31 place
# 9 placed
# 6 places
# 2 placing
# 3 plague
# 5 plain
# 21 plan
# 517 plane
# 70 planes
# 5 planet
# 21 planned
# 11 planning
# 31 plans
# 5 plastic
# 4 plat
# 3 plate
# 22 platinum
# 11 play
# 3 played
# 8 playing
# 14 pleasant
# 3 pleasantly
# 441 please
# 6 pleased
# 5 pleasure
# 14 plenty
# 3 plitt
# 3 ploughs
# 52 pls
# 2 plug
# 53 plus
# 20 plz
# 137 pm
# 3 pnr
# 6 pocket
# 54 point
# 2 pointed
# 2 pointing
# 3 pointless
# 53 points
# 5 police
# 15 policies
# 65 policy
# 2 politely
# 4 pooling
# 60 poor
# 3 poorcustomerservice
# 7 poorly
# 8 poorservice
# 2 pops
# 5 popular
# 3 port
# 2 portcolumbuscmh
# 2 portfolio
# 3 portion
# 10 portland
# 5 pos
# 11 position
# 9 positive
# 2 possibility
# 47 possible
# 14 possibly
# 21 post
# 2 postcode
# 11 posted
# 2 poteettj
# 2 potential
# 2 potentially
# 2 poughkeepsie
# 3 pound
# 20 power
# 28 ppl
# 4 pqd
# 16 pr
# 4 practical
# 7 practice
# 3 practices
# 2 praise
# 2 pray
# 4 praying
# 27 pre
# 5 preboard
# 3 preboarding
# 5 precheck
# 2 preciate
# 2 precious
# 2 precipitation
# 2 predicted
# 5 pref
# 6 prefer
# 2 preference
# 14 preferred
# 2 preflight
# 2 pregnant
# 3 prem
# 22 premier
# 5 premiere
# 14 premium
# 6 prepared
# 2 pres
# 5 present
# 3 presented
# 3 president
# 4 pressure
# 3 pressurization
# 2 pretend
# 35 pretty
# 4 pretzels
# 2 prev
# 6 prevent
# 2 prevention
# 12 previous
# 2 previously
# 33 price
# 3 priced
# 3 priceless
# 16 prices
# 5 pricey
# 6 pricing
# 2 prime
# 3 prince
# 2 princesshalf
# 3 principle
# 11 print
# 5 printed
# 14 prior
# 2 priorities
# 2 prioritize
# 23 priority
# 8 private
# 2 privileges
# 2 prize
# 3 pro
# 3 proactive
# 2 proactively
# 3 prob
# 31 probably
# 97 problem
# 159 problems
# 4 problemss
# 3 probs
# 7 procedure
# 3 procedures
# 3 proceed
# 35 process
# 2 processes
# 2 processing
# 2 product
# 2 prof
# 11 professional
# 2 professionals
# 2 professorpaul
# 3 profile
# 5 profit
# 2 profitability
# 5 profits
# 18 program
# 7 programs
# 6 progress
# 3 project
# 2 projects
# 2 prom
# 14 promise
# 15 promised
# 8 promises
# 3 promising
# 15 promo
# 9 promotion
# 5 promotions
# 13 prompt
# 3 promptly
# 2 prompts
# 5 proof
# 5 proper
# 11 properly
# 4 property
# 3 props
# 2 pros
# 2 protect
# 2 protected
# 2 protection
# 3 protocol
# 4 proud
# 5 prove
# 29 provide
# 19 provided
# 4 providence
# 5 provider
# 12 providing
# 2 proving
# 2 provo
# 7 ps
# 4 psp
# 2 pst
# 3 pt
# 10 pts
# 11 public
# 2 publicly
# 8 puerto
# 10 pull
# 4 pulled
# 7 pulling
# 2 pulse
# 2 pump
# 4 punta
# 2 puppy
# 31 purchase
# 13 purchased
# 3 purchasing
# 2 pure
# 2 purely
# 5 purpose
# 6 push
# 6 pushed
# 5 pushing
# 104 put
# 3 puts
# 5 putting
# 2 pv
# 12 pvd
# 4 pwm
# 2 px
# 2 qantas
# 2 qc
# 2 qd
# 2 qh
# 2 qualifies
# 3 qualify
# 11 quality
# 2 que
# 58 question
# 12 questions
# 6 queue
# 45 quick
# 3 quicker
# 10 quickly
# 2 quiet
# 2 quit
# 6 quite
# 2 quote
# 3 quoted
# 2 quoting
# 2 qw
# 7 race
# 3 radio
# 3 rag
# 4 ragandisney
# 2 rage
# 4 rain
# 14 raise
# 2 raised
# 11 raleigh
# 2 ramada
# 5 ramp
# 2 ramps
# 11 ran
# 5 random
# 4 randomly
# 3 range
# 4 ranked
# 3 rant
# 10 rapid
# 2 rapids
# 2 rare
# 4 rarely
# 18 rate
# 9 rates
# 36 rather
# 2 rating
# 2 rcvd
# 27 rd
# 23 rdu
# 28 reach
# 2 reaches
# 9 reaching
# 2 reactions
# 31 read
# 2 readers
# 6 reading
# 31 ready
# 11 reagan
# 49 real
# 2 reality
# 10 realize
# 6 realized
# 243 really
# 2 rear
# 61 reason
# 8 reasonable
# 10 reasons
# 2 reassign
# 89 rebook
# 78 rebooked
# 2 recap
# 20 receipt
# 3 receipts
# 18 receive
# 69 received
# 4 receiving
# 11 recent
# 5 recently
# 2 recheck
# 3 recieved
# 3 recline
# 2 reclining
# 2 recognition
# 7 recommend
# 3 recommended
# 2 reconsider
# 2 reconsidering
# 22 record
# 2 recorded
# 4 recording
# 5 recourse
# 2 recovered
# 2 recovering
# 4 recovery
# 2 recruiting
# 2 rectified
# 3 rectify
# 14 red
# 6 redcarpet
# 2 reddit
# 13 redeem
# 4 redeemed
# 4 redirected
# 2 reduce
# 2 reduced
# 3 reeks
# 4 ref
# 2 refer
# 7 reference
# 2 referral
# 2 reflect
# 41 reflight
# 2 refrain
# 3 refreshed
# 2 refreshing
# 2 refuel
# 2 refueling
# 115 refund
# 3 refundable
# 17 refunded
# 4 refunding
# 4 refunds
# 12 refuse
# 17 refused
# 3 refuses
# 2 refusing
# 15 regarding
# 3 regardless
# 3 regards
# 3 regional
# 2 register
# 2 registered
# 2 registration
# 4 regret
# 4 regular
# 2 regularly
# 4 regulation
# 2 regulations
# 10 reimburse
# 9 reimbursed
# 11 reimbursement
# 2 reinstate
# 3 reinstated
# 2 reissued
# 13 relate
# 21 relations
# 5 relationship
# 2 relationships
# 4 relative
# 3 relax
# 2 relaxing
# 3 release
# 6 released
# 2 relevant
# 6 reliable
# 3 relief
# 2 remain
# 2 remaining
# 3 remains
# 2 remedy
# 11 remember
# 3 remembered
# 4 remind
# 4 reminded
# 8 reminder
# 3 reminding
# 2 remorse
# 4 remote
# 2 remotely
# 3 removal
# 8 remove
# 2 removed
# 2 reno
# 8 rent
# 15 rental
# 3 renting
# 2 reopens
# 72 rep
# 7 repair
# 2 repeat
# 2 repeated
# 3 repeatedly
# 2 repeating
# 2 replace
# 2 replaced
# 8 replacement
# 5 replacing
# 2 replies
# 59 reply
# 6 replying
# 25 report
# 3 reported
# 3 reports
# 2 represent
# 13 representative
# 3 representatives
# 2 represents
# 17 reps
# 9 republican
# 2 reputation
# 40 request
# 19 requested
# 5 requesting
# 2 requests
# 7 required
# 2 requirement
# 5 requires
# 10 reroute
# 8 rerouted
# 12 res
# 2 resched
# 28 reschedule
# 20 rescheduled
# 9 rescheduling
# 2 resend
# 3 reserv
# 121 reservation
# 38 reservations
# 6 reserve
# 7 reserved
# 6 reset
# 15 resolution
# 3 resolutions
# 12 resolve
# 23 resolved
# 3 resolving
# 2 resources
# 11 respect
# 33 respond
# 6 responded
# 21 responding
# 4 responds
# 145 response
# 6 responses
# 6 responsibility
# 6 responsible
# 4 responsive
# 9 rest
# 4 restore
# 2 restr
# 3 restrictions
# 3 restroom
# 8 result
# 2 resulted
# 2 resulting
# 6 results
# 4 resume
# 2 rethinking
# 3 retrain
# 9 retrieve
# 63 return
# 10 returned
# 10 returning
# 2 reuniting
# 8 revenue
# 5 review
# 2 reviewed
# 2 reviewing
# 10 reward
# 14 rewards
# 4 rfxlv
# 2 rhonda
# 8 ric
# 3 rica
# 4 richard
# 6 rico
# 2 ricoh
# 2 rid
# 22 ride
# 72 ridiculous
# 2 rifle
# 167 right
# 6 rights
# 3 rikrik
# 4 ring
# 3 rings
# 2 rip
# 8 ripoff
# 6 ripped
# 4 risk
# 2 rito
# 2 rivets
# 3 rmpkogwu
# 3 rn
# 2 rno
# 4 road
# 5 roads
# 2 roadwarrior
# 3 roasted
# 3 robbed
# 2 robert
# 2 roberto
# 4 robin
# 2 robot
# 3 robotic
# 8 roc
# 30 rock
# 3 rocked
# 2 rocking
# 11 rocks
# 2 rockstar
# 3 roger
# 2 roll
# 2 rollers
# 2 rolling
# 47 room
# 9 rooms
# 8 rough
# 31 round
# 8 roundtrip
# 28 route
# 2 routed
# 19 routes
# 8 routing
# 53 row
# 10 rows
# 3 roxydigital
# 2 royally
# 2 rps
# 15 rr
# 14 rsw
# 95 rt
# 2 rtb
# 2 ru
# 102 rude
# 2 rudely
# 2 rudeness
# 4 rudest
# 21 ruined
# 12 ruining
# 4 rule
# 15 rules
# 2 rum
# 2 rumors
# 35 run
# 2 runaround
# 27 running
# 3 runs
# 51 runway
# 2 runways
# 3 rushed
# 3 ruth
# 3 rx
# 2 sabre
# 4 sacramento
# 28 sad
# 8 sadly
# 4 safari
# 16 safe
# 11 safely
# 35 safety
# 2 saga
# 138 said
# 11 sale
# 4 sales
# 2 sally
# 6 salt
# 2 salted
# 2 samartzis
# 2 sammi
# 70 san
# 2 sandiego
# 3 sandwich
# 3 sanfrancisco
# 2 sanitized
# 2 sanity
# 4 santa
# 7 sarcasm
# 2 sass
# 40 sat
# 2 satisfactory
# 2 satisfied
# 23 saturday
# 2 sav
# 6 savannah
# 16 save
# 8 saved
# 2 savethediagonals
# 9 saving
# 2 savings
# 25 saw
# 92 say
# 3 sayin
# 43 saying
# 119 says
# 5 sb
# 2 sba
# 4 sc
# 5 scale
# 4 scam
# 5 scan
# 3 scanned
# 5 scared
# 2 scattered
# 8 scavenger
# 2 sch
# 4 sched
# 29 schedule
# 48 scheduled
# 2 schedules
# 6 scheduling
# 11 school
# 2 science
# 2 sciencebehindtheexperience
# 3 scollegelondon
# 2 scotch
# 4 scott
# 2 scratching
# 3 screaming
# 13 screen
# 4 screens
# 2 screenshot
# 14 screw
# 19 screwed
# 4 screwing
# 2 screws
# 2 sd
# 3 sdf
# 16 sea
# 2 sean
# 6 search
# 2 searched
# 4 searching
# 2 season
# 222 seat
# 3 seatac
# 2 seatbelt
# 7 seated
# 24 seating
# 166 seats
# 15 seattle
# 5 sec
# 40 second
# 5 seconds
# 4 section
# 5 secure
# 3 secured
# 19 security
# 217 see
# 10 seeing
# 7 seeks
# 32 seem
# 4 seemed
# 46 seems
# 22 seen
# 3 sees
# 3 seg
# 4 segment
# 4 segments
# 14 select
# 4 selected
# 2 selection
# 7 self
# 8 selfie
# 2 selfies
# 14 sell
# 2 selling
# 82 send
# 27 sending
# 2 senior
# 28 sense
# 2 sensitive
# 155 sent
# 3 sentiment
# 2 sentinel
# 4 sep
# 9 separate
# 2 separated
# 2 separately
# 5 sept
# 5 september
# 3 series
# 15 serious
# 64 seriously
# 5 serv
# 6 serve
# 2 served
# 2 serves
# 753 service
# 3 servicefail
# 29 services
# 6 serving
# 32 set
# 2 setting
# 2 settle
# 3 settled
# 2 setup
# 3 seven
# 26 several
# 2 severely
# 2 sexy
# 16 sf
# 121 sfo
# 2 sh
# 2 shades
# 2 shaking
# 4 shall
# 13 shame
# 10 shameful
# 2 shameonyou
# 2 shampoo
# 2 shanghai
# 4 shannon
# 2 shannonwoodward
# 29 share
# 3 shared
# 3 shares
# 7 sharing
# 2 shenanigans
# 2 shes
# 2 shift
# 2 shifts
# 4 ship
# 2 shipped
# 2 shirts
# 23
